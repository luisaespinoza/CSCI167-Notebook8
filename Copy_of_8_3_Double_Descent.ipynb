# %% [markdown]
# <a href="https://colab.research.google.com/github/luisaespinoza/CSCI167-Notebook8/blob/main/Copy_of_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-d9_x3lx5
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-d9_x3lx5
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=039a11d795fa0294040241a81233efc621e8f97d83f5f310a6c182d9c554d6c6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p838zxg0/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 100
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 100
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# 400

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301907, train error 89.30,  test loss 2.302091, test error 89.75
# Epoch   100, train loss 1.872876, train error 71.22,  test loss 1.722975, test error 67.82
# Epoch   200, train loss 1.862078, train error 70.00,  test loss 1.712574, test error 67.97
# Epoch   300, train loss 1.852115, train error 70.00,  test loss 1.698739, test error 68.82
# Epoch   400, train loss 1.849228, train error 69.80,  test loss 1.701030, test error 68.05
# Epoch   500, train loss 1.849807, train error 69.95,  test loss 1.697520, test error 68.95
# Epoch   600, train loss 1.848728, train error 69.70,  test loss 1.695745, test error 68.28
# Epoch   700, train loss 1.848207, train error 69.70,  test loss 1.698639, test error 68.12
# Epoch   800, train loss 1.847703, train error 69.82,  test loss 1.697197, test error 68.00
# Epoch   900, train loss 1.851651, train error 70.68,  test loss 1.700013, test error 68.95
# Training model with   4 hidden variables
# Epoch     0, train loss 2.297385, train error 91.07,  test loss 2.295901, test error 90.32
# Epoch   100, train loss 1.757869, train error 65.95,  test loss 1.593625, test error 62.72
# Epoch   200, train loss 1.687418, train error 61.80,  test loss 1.500546, test error 57.17
# Epoch   300, train loss 1.684456, train error 61.50,  test loss 1.505125, test error 57.92
# Epoch   400, train loss 1.681581, train error 61.38,  test loss 1.496382, test error 57.62
# Epoch   500, train loss 1.677077, train error 61.22,  test loss 1.495471, test error 57.08
# Epoch   600, train loss 1.687356, train error 61.10,  test loss 1.507659, test error 58.03
# Epoch   700, train loss 1.676853, train error 61.83,  test loss 1.492209, test error 57.33
# Epoch   800, train loss 1.674950, train error 60.88,  test loss 1.490880, test error 57.45
# Epoch   900, train loss 1.674911, train error 61.25,  test loss 1.487897, test error 57.45
# Training model with   6 hidden variables
# Epoch     0, train loss 2.293140, train error 88.22,  test loss 2.281347, test error 88.00
# Epoch   100, train loss 1.683921, train error 59.65,  test loss 1.478600, test error 56.75
# Epoch   200, train loss 1.660372, train error 58.20,  test loss 1.467226, test error 57.05
# Epoch   300, train loss 1.650289, train error 57.20,  test loss 1.469427, test error 56.78
# Epoch   400, train loss 1.641188, train error 57.83,  test loss 1.459814, test error 56.42
# Epoch   500, train loss 1.639024, train error 58.40,  test loss 1.463439, test error 56.75
# Epoch   600, train loss 1.640270, train error 57.67,  test loss 1.476397, test error 57.42
# Epoch   700, train loss 1.634787, train error 57.60,  test loss 1.470460, test error 56.70
# Epoch   800, train loss 1.632599, train error 57.08,  test loss 1.464633, test error 56.22
# Epoch   900, train loss 1.630746, train error 57.25,  test loss 1.463690, test error 56.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.264739, train error 84.25,  test loss 2.262374, test error 84.47
# Epoch   100, train loss 1.589038, train error 55.40,  test loss 1.414705, test error 54.25
# Epoch   200, train loss 1.559203, train error 54.20,  test loss 1.396328, test error 53.15
# Epoch   300, train loss 1.548072, train error 54.05,  test loss 1.389993, test error 52.50
# Epoch   400, train loss 1.535990, train error 53.40,  test loss 1.393587, test error 52.75
# Epoch   500, train loss 1.540341, train error 53.67,  test loss 1.410570, test error 53.38
# Epoch   600, train loss 1.527950, train error 52.67,  test loss 1.411695, test error 52.67
# Epoch   700, train loss 1.527652, train error 52.95,  test loss 1.414467, test error 52.70
# Epoch   800, train loss 1.527584, train error 53.33,  test loss 1.429181, test error 53.47
# Epoch   900, train loss 1.522854, train error 52.72,  test loss 1.434383, test error 53.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.218678, train error 82.97,  test loss 2.194227, test error 81.28
# Epoch   100, train loss 1.550663, train error 54.95,  test loss 1.427056, test error 53.40
# Epoch   200, train loss 1.479038, train error 51.92,  test loss 1.356203, test error 50.20
# Epoch   300, train loss 1.454634, train error 50.45,  test loss 1.341736, test error 49.50
# Epoch   400, train loss 1.443665, train error 50.65,  test loss 1.349327, test error 49.15
# Epoch   500, train loss 1.437201, train error 49.83,  test loss 1.346175, test error 49.92
# Epoch   600, train loss 1.428429, train error 50.00,  test loss 1.354955, test error 50.33
# Epoch   700, train loss 1.424120, train error 50.22,  test loss 1.362899, test error 50.05
# Epoch   800, train loss 1.419780, train error 49.72,  test loss 1.368705, test error 50.45
# Epoch   900, train loss 1.419963, train error 49.42,  test loss 1.369828, test error 50.25
# Training model with  14 hidden variables
# Epoch     0, train loss 2.288992, train error 84.55,  test loss 2.286429, test error 84.00
# Epoch   100, train loss 1.471191, train error 50.67,  test loss 1.384983, test error 52.33
# Epoch   200, train loss 1.337718, train error 45.05,  test loss 1.287220, test error 48.50
# Epoch   300, train loss 1.312288, train error 44.42,  test loss 1.298830, test error 47.97
# Epoch   400, train loss 1.310229, train error 44.15,  test loss 1.328227, test error 48.75
# Epoch   500, train loss 1.288287, train error 43.97,  test loss 1.326727, test error 48.80
# Epoch   600, train loss 1.284514, train error 43.22,  test loss 1.340207, test error 48.97
# Epoch   700, train loss 1.278315, train error 42.72,  test loss 1.354448, test error 49.45
# Epoch   800, train loss 1.276719, train error 42.10,  test loss 1.349466, test error 49.17
# Epoch   900, train loss 1.267399, train error 41.90,  test loss 1.360550, test error 49.55
# Training model with  18 hidden variables
# Epoch     0, train loss 2.237127, train error 84.03,  test loss 2.228465, test error 83.90
# Epoch   100, train loss 1.373119, train error 46.40,  test loss 1.400393, test error 53.28
# Epoch   200, train loss 1.266769, train error 42.60,  test loss 1.436507, test error 52.03
# Epoch   300, train loss 1.224840, train error 41.05,  test loss 1.478743, test error 52.20
# Epoch   400, train loss 1.205964, train error 40.83,  test loss 1.526026, test error 52.17
# Epoch   500, train loss 1.183842, train error 40.00,  test loss 1.518408, test error 52.33
# Epoch   600, train loss 1.189325, train error 40.85,  test loss 1.534294, test error 52.08
# Epoch   700, train loss 1.176803, train error 39.62,  test loss 1.539829, test error 52.72
# Epoch   800, train loss 1.168479, train error 39.75,  test loss 1.554880, test error 52.40
# Epoch   900, train loss 1.165625, train error 39.15,  test loss 1.555902, test error 52.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.284289, train error 85.75,  test loss 2.272835, test error 85.05
# Epoch   100, train loss 1.274854, train error 42.20,  test loss 1.282385, test error 47.38
# Epoch   200, train loss 1.164316, train error 38.80,  test loss 1.346286, test error 48.53
# Epoch   300, train loss 1.111784, train error 36.47,  test loss 1.423406, test error 50.72
# Epoch   400, train loss 1.074880, train error 36.45,  test loss 1.498425, test error 51.42
# Epoch   500, train loss 1.051255, train error 35.60,  test loss 1.542306, test error 52.38
# Epoch   600, train loss 1.045794, train error 34.82,  test loss 1.583603, test error 52.50
# Epoch   700, train loss 1.021569, train error 33.78,  test loss 1.611463, test error 52.58
# Epoch   800, train loss 1.026938, train error 33.82,  test loss 1.632409, test error 52.85
# Epoch   900, train loss 1.024617, train error 34.62,  test loss 1.672603, test error 52.83
# Training model with  26 hidden variables
# Epoch     0, train loss 2.117106, train error 79.07,  test loss 2.092712, test error 77.68
# Epoch   100, train loss 1.193885, train error 39.60,  test loss 1.272360, test error 47.10
# Epoch   200, train loss 1.058592, train error 35.22,  test loss 1.356097, test error 47.62
# Epoch   300, train loss 0.974504, train error 32.35,  test loss 1.486710, test error 48.85
# Epoch   400, train loss 0.926094, train error 31.40,  test loss 1.593867, test error 50.47
# Epoch   500, train loss 0.902330, train error 29.78,  test loss 1.705673, test error 51.75
# Epoch   600, train loss 0.882543, train error 29.53,  test loss 1.778095, test error 52.25
# Epoch   700, train loss 0.860403, train error 27.97,  test loss 1.855248, test error 52.78
# Epoch   800, train loss 0.849980, train error 27.43,  test loss 1.899391, test error 52.85
# Epoch   900, train loss 0.838819, train error 27.32,  test loss 1.980094, test error 53.83
# Training model with  30 hidden variables
# Epoch     0, train loss 2.157461, train error 80.53,  test loss 2.124244, test error 79.90
# Epoch   100, train loss 1.152686, train error 38.03,  test loss 1.391011, test error 49.80
# Epoch   200, train loss 0.957792, train error 30.47,  test loss 1.592495, test error 52.05
# Epoch   300, train loss 0.846555, train error 28.57,  test loss 1.818237, test error 53.33
# Epoch   400, train loss 0.796369, train error 27.35,  test loss 1.980342, test error 53.65
# Epoch   500, train loss 0.748922, train error 25.47,  test loss 2.139488, test error 55.05
# Epoch   600, train loss 0.738795, train error 25.22,  test loss 2.342257, test error 55.42
# Epoch   700, train loss 0.696522, train error 23.82,  test loss 2.446602, test error 55.95
# Epoch   800, train loss 0.691879, train error 23.70,  test loss 2.577564, test error 56.62
# Epoch   900, train loss 0.700118, train error 24.75,  test loss 2.683611, test error 56.00
# Training model with  35 hidden variables
# Epoch     0, train loss 2.127218, train error 77.85,  test loss 2.102527, test error 77.82
# Epoch   100, train loss 1.007058, train error 32.72,  test loss 1.371998, test error 49.45
# Epoch   200, train loss 0.799955, train error 26.95,  test loss 1.618631, test error 50.08
# Epoch   300, train loss 0.666861, train error 22.53,  test loss 1.929662, test error 51.83
# Epoch   400, train loss 0.600798, train error 20.28,  test loss 2.317493, test error 54.22
# Epoch   500, train loss 0.573674, train error 19.80,  test loss 2.671553, test error 54.72
# Epoch   600, train loss 0.559386, train error 19.70,  test loss 2.938751, test error 53.83
# Epoch   700, train loss 0.485601, train error 17.00,  test loss 3.192249, test error 55.25
# Epoch   800, train loss 0.466717, train error 16.30,  test loss 3.431517, test error 56.30
# Epoch   900, train loss 0.470946, train error 17.10,  test loss 3.659391, test error 56.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.095601, train error 77.05,  test loss 2.067062, test error 77.03
# Epoch   100, train loss 0.886998, train error 29.10,  test loss 1.431996, test error 49.85
# Epoch   200, train loss 0.639695, train error 21.00,  test loss 1.929817, test error 53.70
# Epoch   300, train loss 0.530370, train error 18.65,  test loss 2.510208, test error 53.95
# Epoch   400, train loss 0.393414, train error 12.95,  test loss 3.095864, test error 55.20
# Epoch   500, train loss 0.375537, train error 13.05,  test loss 3.773129, test error 54.95
# Epoch   600, train loss 0.360282, train error 13.32,  test loss 4.581562, test error 55.88
# Epoch   700, train loss 0.269869, train error 9.40,  test loss 5.168931, test error 55.67
# Epoch   800, train loss 0.246459, train error 8.62,  test loss 5.610562, test error 55.60
# Epoch   900, train loss 0.251332, train error 9.22,  test loss 6.268916, test error 56.10
# Training model with  45 hidden variables
# Epoch     0, train loss 2.068105, train error 77.15,  test loss 2.025578, test error 76.43
# Epoch   100, train loss 0.801065, train error 25.18,  test loss 1.526901, test error 50.28
# Epoch   200, train loss 0.500373, train error 16.05,  test loss 2.278409, test error 53.78
# Epoch   300, train loss 0.295647, train error 8.28,  test loss 3.296137, test error 55.70
# Epoch   400, train loss 0.200261, train error 6.15,  test loss 4.597423, test error 57.42
# Epoch   500, train loss 0.160342, train error 5.20,  test loss 5.786861, test error 57.15
# Epoch   600, train loss 0.120513, train error 4.03,  test loss 7.080965, test error 57.65
# Epoch   700, train loss 0.013335, train error 0.00,  test loss 8.098484, test error 57.60
# Epoch   800, train loss 0.008883, train error 0.00,  test loss 8.779150, test error 57.58
# Epoch   900, train loss 0.006782, train error 0.00,  test loss 9.295607, test error 57.72
# Training model with  50 hidden variables
# Epoch     0, train loss 2.085471, train error 77.15,  test loss 2.042527, test error 76.20
# Epoch   100, train loss 0.726543, train error 23.10,  test loss 1.581541, test error 50.60
# Epoch   200, train loss 0.393617, train error 13.60,  test loss 2.637498, test error 54.25
# Epoch   300, train loss 0.148603, train error 3.70,  test loss 4.179637, test error 55.97
# Epoch   400, train loss 0.071038, train error 1.18,  test loss 5.833089, test error 57.60
# Epoch   500, train loss 0.012581, train error 0.00,  test loss 6.829480, test error 56.92
# Epoch   600, train loss 0.007896, train error 0.00,  test loss 7.456987, test error 57.03
# Epoch   700, train loss 0.005738, train error 0.00,  test loss 7.920728, test error 57.12
# Epoch   800, train loss 0.004425, train error 0.00,  test loss 8.306250, test error 57.17
# Epoch   900, train loss 0.003598, train error 0.00,  test loss 8.605780, test error 57.12
# Training model with  55 hidden variables
# Epoch     0, train loss 2.061412, train error 77.35,  test loss 2.002148, test error 77.32
# Epoch   100, train loss 0.634452, train error 19.95,  test loss 1.552979, test error 48.80
# Epoch   200, train loss 0.193991, train error 4.12,  test loss 2.956676, test error 52.12
# Epoch   300, train loss 0.035852, train error 0.03,  test loss 4.615584, test error 53.85
# Epoch   400, train loss 0.014057, train error 0.00,  test loss 5.621930, test error 54.42
# Epoch   500, train loss 0.008163, train error 0.00,  test loss 6.218650, test error 54.55
# Epoch   600, train loss 0.005586, train error 0.00,  test loss 6.649342, test error 54.33
# Epoch   700, train loss 0.004155, train error 0.00,  test loss 6.981952, test error 54.53
# Epoch   800, train loss 0.003282, train error 0.00,  test loss 7.254928, test error 54.60
# Epoch   900, train loss 0.002691, train error 0.00,  test loss 7.486000, test error 54.55
# Training model with  60 hidden variables
# Epoch     0, train loss 2.069197, train error 77.47,  test loss 2.009481, test error 78.22
# Epoch   100, train loss 0.549724, train error 16.75,  test loss 1.707801, test error 50.33
# Epoch   200, train loss 0.124242, train error 1.60,  test loss 3.215314, test error 52.38
# Epoch   300, train loss 0.021387, train error 0.00,  test loss 4.545646, test error 52.97
# Epoch   400, train loss 0.009773, train error 0.00,  test loss 5.246867, test error 52.78
# Epoch   500, train loss 0.006106, train error 0.00,  test loss 5.691111, test error 52.97
# Epoch   600, train loss 0.004360, train error 0.00,  test loss 6.021217, test error 53.12
# Epoch   700, train loss 0.003337, train error 0.00,  test loss 6.282261, test error 53.35
# Epoch   800, train loss 0.002672, train error 0.00,  test loss 6.499318, test error 53.47
# Epoch   900, train loss 0.002219, train error 0.00,  test loss 6.684735, test error 53.58
# Training model with  70 hidden variables
# Epoch     0, train loss 2.012907, train error 74.80,  test loss 1.955785, test error 74.32
# Epoch   100, train loss 0.376138, train error 9.55,  test loss 1.919230, test error 52.12
# Epoch   200, train loss 0.039037, train error 0.03,  test loss 3.564062, test error 53.40
# Epoch   300, train loss 0.012414, train error 0.00,  test loss 4.396917, test error 53.33
# Epoch   400, train loss 0.006774, train error 0.00,  test loss 4.859039, test error 53.25
# Epoch   500, train loss 0.004507, train error 0.00,  test loss 5.188590, test error 53.42
# Epoch   600, train loss 0.003320, train error 0.00,  test loss 5.431947, test error 53.42
# Epoch   700, train loss 0.002597, train error 0.00,  test loss 5.630410, test error 53.45
# Epoch   800, train loss 0.002116, train error 0.00,  test loss 5.797244, test error 53.42
# Epoch   900, train loss 0.001773, train error 0.00,  test loss 5.938577, test error 53.40
# Training model with  80 hidden variables
# Epoch     0, train loss 1.975304, train error 73.88,  test loss 1.908284, test error 73.53
# Epoch   100, train loss 0.199504, train error 2.78,  test loss 2.062355, test error 50.85
# Epoch   200, train loss 0.019205, train error 0.00,  test loss 3.395229, test error 51.58
# Epoch   300, train loss 0.007846, train error 0.00,  test loss 3.931508, test error 51.42
# Epoch   400, train loss 0.004677, train error 0.00,  test loss 4.253532, test error 51.72
# Epoch   500, train loss 0.003251, train error 0.00,  test loss 4.483140, test error 51.88
# Epoch   600, train loss 0.002440, train error 0.00,  test loss 4.658759, test error 51.85
# Epoch   700, train loss 0.001940, train error 0.00,  test loss 4.804083, test error 51.97
# Epoch   800, train loss 0.001599, train error 0.00,  test loss 4.928088, test error 51.92
# Epoch   900, train loss 0.001352, train error 0.00,  test loss 5.033204, test error 51.97
# Training model with  90 hidden variables
# Epoch     0, train loss 1.982690, train error 74.55,  test loss 1.892004, test error 74.60
# Epoch   100, train loss 0.142901, train error 1.20,  test loss 2.168380, test error 50.22
# Epoch   200, train loss 0.015003, train error 0.00,  test loss 3.204368, test error 50.72
# Epoch   300, train loss 0.006574, train error 0.00,  test loss 3.632307, test error 51.03
# Epoch   400, train loss 0.003996, train error 0.00,  test loss 3.905566, test error 51.12
# Epoch   500, train loss 0.002811, train error 0.00,  test loss 4.097028, test error 51.10
# Epoch   600, train loss 0.002141, train error 0.00,  test loss 4.248324, test error 51.17
# Epoch   700, train loss 0.001711, train error 0.00,  test loss 4.371934, test error 51.25
# Epoch   800, train loss 0.001416, train error 0.00,  test loss 4.476517, test error 51.28
# Epoch   900, train loss 0.001203, train error 0.00,  test loss 4.567213, test error 51.28
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015785, train error 73.45,  test loss 1.969833, test error 75.18
# Epoch   100, train loss 0.102919, train error 0.40,  test loss 2.298862, test error 52.00
# Epoch   200, train loss 0.012506, train error 0.00,  test loss 3.164126, test error 52.80
# Epoch   300, train loss 0.005787, train error 0.00,  test loss 3.544496, test error 52.83
# Epoch   400, train loss 0.003604, train error 0.00,  test loss 3.780791, test error 52.90
# Epoch   500, train loss 0.002556, train error 0.00,  test loss 3.953799, test error 52.83
# Epoch   600, train loss 0.001955, train error 0.00,  test loss 4.089506, test error 52.78
# Epoch   700, train loss 0.001569, train error 0.00,  test loss 4.200833, test error 52.72
# Epoch   800, train loss 0.001302, train error 0.00,  test loss 4.295087, test error 52.65
# Epoch   900, train loss 0.001108, train error 0.00,  test loss 4.376909, test error 52.65
# Training model with 120 hidden variables
# Epoch     0, train loss 1.989334, train error 72.75,  test loss 1.930974, test error 75.03
# Epoch   100, train loss 0.050873, train error 0.00,  test loss 2.171807, test error 49.55
# Epoch   200, train loss 0.009612, train error 0.00,  test loss 2.762314, test error 50.12
# Epoch   300, train loss 0.004750, train error 0.00,  test loss 3.033914, test error 50.38
# Epoch   400, train loss 0.003036, train error 0.00,  test loss 3.208198, test error 50.25
# Epoch   500, train loss 0.002188, train error 0.00,  test loss 3.336919, test error 50.17
# Epoch   600, train loss 0.001691, train error 0.00,  test loss 3.439062, test error 50.10
# Epoch   700, train loss 0.001367, train error 0.00,  test loss 3.522873, test error 50.08
# Epoch   800, train loss 0.001141, train error 0.00,  test loss 3.594661, test error 50.05
# Epoch   900, train loss 0.000975, train error 0.00,  test loss 3.657849, test error 49.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962285, train error 72.28,  test loss 1.874353, test error 72.85
# Epoch   100, train loss 0.038213, train error 0.00,  test loss 2.107340, test error 49.15
# Epoch   200, train loss 0.008343, train error 0.00,  test loss 2.594532, test error 49.08
# Epoch   300, train loss 0.004239, train error 0.00,  test loss 2.817610, test error 49.30
# Epoch   400, train loss 0.002752, train error 0.00,  test loss 2.969996, test error 49.28
# Epoch   500, train loss 0.001998, train error 0.00,  test loss 3.080394, test error 49.33
# Epoch   600, train loss 0.001552, train error 0.00,  test loss 3.169719, test error 49.20
# Epoch   700, train loss 0.001259, train error 0.00,  test loss 3.243611, test error 49.15
# Epoch   800, train loss 0.001054, train error 0.00,  test loss 3.306142, test error 49.12
# Epoch   900, train loss 0.000903, train error 0.00,  test loss 3.361777, test error 49.05
# Training model with 160 hidden variables
# Epoch     0, train loss 1.960666, train error 71.90,  test loss 1.882628, test error 73.05
# Epoch   100, train loss 0.028110, train error 0.00,  test loss 2.123497, test error 49.45
# Epoch   200, train loss 0.007145, train error 0.00,  test loss 2.524596, test error 48.97
# Epoch   300, train loss 0.003760, train error 0.00,  test loss 2.724325, test error 48.92
# Epoch   400, train loss 0.002475, train error 0.00,  test loss 2.856981, test error 48.92
# Epoch   500, train loss 0.001813, train error 0.00,  test loss 2.957872, test error 48.88
# Epoch   600, train loss 0.001415, train error 0.00,  test loss 3.036779, test error 49.00
# Epoch   700, train loss 0.001153, train error 0.00,  test loss 3.102757, test error 49.12
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 3.159846, test error 49.05
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.210105, test error 49.00
# Training model with 180 hidden variables
# Epoch     0, train loss 1.918240, train error 69.80,  test loss 1.846254, test error 71.30
# Epoch   100, train loss 0.024307, train error 0.00,  test loss 2.061029, test error 48.83
# Epoch   200, train loss 0.006567, train error 0.00,  test loss 2.415555, test error 48.70
# Epoch   300, train loss 0.003521, train error 0.00,  test loss 2.594291, test error 48.55
# Epoch   400, train loss 0.002333, train error 0.00,  test loss 2.714249, test error 48.55
# Epoch   500, train loss 0.001717, train error 0.00,  test loss 2.804557, test error 48.50
# Epoch   600, train loss 0.001345, train error 0.00,  test loss 2.878380, test error 48.53
# Epoch   700, train loss 0.001098, train error 0.00,  test loss 2.938344, test error 48.55
# Epoch   800, train loss 0.000923, train error 0.00,  test loss 2.990417, test error 48.50
# Epoch   900, train loss 0.000794, train error 0.00,  test loss 3.036032, test error 48.53
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918255, train error 70.93,  test loss 1.846966, test error 72.85
# Epoch   100, train loss 0.022396, train error 0.00,  test loss 2.062179, test error 49.15
# Epoch   200, train loss 0.006222, train error 0.00,  test loss 2.394673, test error 49.08
# Epoch   300, train loss 0.003361, train error 0.00,  test loss 2.566780, test error 49.12
# Epoch   400, train loss 0.002238, train error 0.00,  test loss 2.682751, test error 49.20
# Epoch   500, train loss 0.001653, train error 0.00,  test loss 2.768824, test error 49.17
# Epoch   600, train loss 0.001296, train error 0.00,  test loss 2.838285, test error 49.30
# Epoch   700, train loss 0.001060, train error 0.00,  test loss 2.896010, test error 49.28
# Epoch   800, train loss 0.000892, train error 0.00,  test loss 2.945290, test error 49.25
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.989032, test error 49.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.881325, train error 68.95,  test loss 1.802647, test error 71.43
# Epoch   100, train loss 0.016537, train error 0.00,  test loss 1.908412, test error 47.53
# Epoch   200, train loss 0.005280, train error 0.00,  test loss 2.167222, test error 47.35
# Epoch   300, train loss 0.002948, train error 0.00,  test loss 2.302254, test error 47.15
# Epoch   400, train loss 0.001992, train error 0.00,  test loss 2.394253, test error 47.17
# Epoch   500, train loss 0.001484, train error 0.00,  test loss 2.464807, test error 47.00
# Epoch   600, train loss 0.001172, train error 0.00,  test loss 2.521572, test error 47.08
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.569048, test error 47.10
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.610097, test error 47.12
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.646163, test error 47.15
# Training model with 300 hidden variables
# Epoch     0, train loss 1.890089, train error 67.18,  test loss 1.823648, test error 70.05
# Epoch   100, train loss 0.014356, train error 0.00,  test loss 1.862150, test error 46.08
# Epoch   200, train loss 0.004789, train error 0.00,  test loss 2.085355, test error 46.12
# Epoch   300, train loss 0.002713, train error 0.00,  test loss 2.205028, test error 46.25
# Epoch   400, train loss 0.001847, train error 0.00,  test loss 2.287859, test error 46.30
# Epoch   500, train loss 0.001382, train error 0.00,  test loss 2.350314, test error 46.30
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.401011, test error 46.08
# Epoch   700, train loss 0.000902, train error 0.00,  test loss 2.443626, test error 46.03
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.480350, test error 46.00
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.512578, test error 45.97
# Training model with 400 hidden variables
# Epoch     0, train loss 1.862178, train error 66.43,  test loss 1.809369, test error 70.07
# Epoch   100, train loss 0.011597, train error 0.00,  test loss 1.763340, test error 45.70
# Epoch   200, train loss 0.004141, train error 0.00,  test loss 1.941013, test error 45.75
# Epoch   300, train loss 0.002396, train error 0.00,  test loss 2.041006, test error 45.75
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.108703, test error 45.60
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.161892, test error 45.62
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.204166, test error 45.62
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.240211, test error 45.60
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.271460, test error 45.75
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.298625, test error 45.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()

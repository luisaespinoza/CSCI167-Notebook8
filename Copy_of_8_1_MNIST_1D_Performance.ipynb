# %% [markdown]
# <a href="https://colab.research.google.com/github/luisaespinoza/CSCI167-Notebook8/blob/main/Copy_of_8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-pu5y6s9x
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-pu5y6s9x
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=8781fdc8877d3854837e4bcb8a42bbd26f6f4500e5bc45f772f54fc54bd1cda2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hx2592zg/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
# model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k), torch.nn.ReLU(), torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if type(layer_in) == torch.nn.Linear:
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.01)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.632505, train error 63.15,  test loss 1.743659, test error 68.10
# Epoch     1, train loss 1.396444, train error 52.10,  test loss 1.520028, test error 61.80
# Epoch     2, train loss 1.242173, train error 43.65,  test loss 1.389112, test error 53.80
# Epoch     3, train loss 1.160849, train error 41.92,  test loss 1.302439, test error 48.70
# Epoch     4, train loss 1.061924, train error 38.08,  test loss 1.237119, test error 49.00
# Epoch     5, train loss 1.006155, train error 35.82,  test loss 1.199777, test error 46.80
# Epoch     6, train loss 0.975336, train error 36.08,  test loss 1.184839, test error 47.00
# Epoch     7, train loss 0.925023, train error 34.00,  test loss 1.185388, test error 45.50
# Epoch     8, train loss 0.856159, train error 30.40,  test loss 1.125679, test error 43.20
# Epoch     9, train loss 0.857384, train error 31.20,  test loss 1.124774, test error 42.50
# Epoch    10, train loss 0.801644, train error 28.22,  test loss 1.098924, test error 42.40
# Epoch    11, train loss 0.789804, train error 27.05,  test loss 1.093030, test error 42.60
# Epoch    12, train loss 0.770956, train error 26.40,  test loss 1.082956, test error 41.70
# Epoch    13, train loss 0.775673, train error 27.57,  test loss 1.110976, test error 42.20
# Epoch    14, train loss 0.748074, train error 25.65,  test loss 1.071362, test error 40.10
# Epoch    15, train loss 0.731839, train error 25.35,  test loss 1.087240, test error 41.60
# Epoch    16, train loss 0.723376, train error 25.30,  test loss 1.084234, test error 40.90
# Epoch    17, train loss 0.712841, train error 25.15,  test loss 1.086717, test error 42.30
# Epoch    18, train loss 0.708589, train error 24.28,  test loss 1.095582, test error 40.30
# Epoch    19, train loss 0.692513, train error 23.70,  test loss 1.095955, test error 42.10
# Epoch    20, train loss 0.677282, train error 22.40,  test loss 1.079095, test error 41.20
# Epoch    21, train loss 0.671763, train error 22.97,  test loss 1.077079, test error 40.90
# Epoch    22, train loss 0.668109, train error 21.95,  test loss 1.076144, test error 40.40
# Epoch    23, train loss 0.662390, train error 22.15,  test loss 1.081235, test error 41.00
# Epoch    24, train loss 0.663143, train error 21.85,  test loss 1.088739, test error 40.40
# Epoch    25, train loss 0.659756, train error 22.47,  test loss 1.098065, test error 40.80
# Epoch    26, train loss 0.656599, train error 22.05,  test loss 1.101563, test error 40.50
# Epoch    27, train loss 0.648774, train error 22.03,  test loss 1.090852, test error 41.20
# Epoch    28, train loss 0.642729, train error 20.90,  test loss 1.094636, test error 41.20
# Epoch    29, train loss 0.636512, train error 21.15,  test loss 1.094753, test error 41.40
# Epoch    30, train loss 0.629683, train error 20.35,  test loss 1.089590, test error 40.80
# Epoch    31, train loss 0.626793, train error 20.07,  test loss 1.093588, test error 40.80
# Epoch    32, train loss 0.625587, train error 20.22,  test loss 1.091635, test error 40.70
# Epoch    33, train loss 0.623623, train error 20.65,  test loss 1.093611, test error 41.10
# Epoch    34, train loss 0.620364, train error 19.90,  test loss 1.093670, test error 40.10
# Epoch    35, train loss 0.619311, train error 19.93,  test loss 1.092306, test error 41.30
# Epoch    36, train loss 0.615957, train error 19.90,  test loss 1.091208, test error 40.60
# Epoch    37, train loss 0.614308, train error 19.90,  test loss 1.097649, test error 40.80
# Epoch    38, train loss 0.614162, train error 19.90,  test loss 1.097313, test error 41.20
# Epoch    39, train loss 0.609871, train error 19.75,  test loss 1.100526, test error 41.30
# Epoch    40, train loss 0.608200, train error 19.53,  test loss 1.099061, test error 41.00
# Epoch    41, train loss 0.606795, train error 19.53,  test loss 1.100041, test error 41.30
# Epoch    42, train loss 0.605692, train error 19.53,  test loss 1.098772, test error 41.10
# Epoch    43, train loss 0.604739, train error 19.55,  test loss 1.098253, test error 41.20
# Epoch    44, train loss 0.603596, train error 19.60,  test loss 1.098233, test error 41.10
# Epoch    45, train loss 0.602637, train error 19.28,  test loss 1.099274, test error 41.60
# Epoch    46, train loss 0.601614, train error 19.30,  test loss 1.100083, test error 41.10
# Epoch    47, train loss 0.600692, train error 19.28,  test loss 1.101943, test error 41.60
# Epoch    48, train loss 0.599638, train error 19.25,  test loss 1.099994, test error 41.00
# Epoch    49, train loss 0.598711, train error 19.18,  test loss 1.101890, test error 41.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
#adjusting hyperparameters to explore outcomes


D_i = 40    # Input dimensions
D_k = 200   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
# model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k,), torch.nn.ReLU(), torch.nn.Linear(D_k, D_k), torch.nn.ReLU(), torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if type(layer_in) == torch.nn.Linear:
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.01)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=200, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=200, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.533969, train error 58.95,  test loss 1.624857, test error 64.50
# Epoch     1, train loss 1.218807, train error 43.42,  test loss 1.411259, test error 55.50
# Epoch     2, train loss 1.014607, train error 36.03,  test loss 1.304744, test error 50.30
# Epoch     3, train loss 0.848892, train error 29.28,  test loss 1.227541, test error 46.70
# Epoch     4, train loss 0.700486, train error 23.22,  test loss 1.146041, test error 45.40
# Epoch     5, train loss 0.601378, train error 20.12,  test loss 1.157570, test error 42.60
# Epoch     6, train loss 0.483674, train error 14.50,  test loss 1.098483, test error 41.80
# Epoch     7, train loss 0.376494, train error 10.07,  test loss 1.060655, test error 38.90
# Epoch     8, train loss 0.333322, train error 9.40,  test loss 1.099683, test error 39.00
# Epoch     9, train loss 0.234032, train error 5.35,  test loss 1.099868, test error 37.60
# Epoch    10, train loss 0.172866, train error 2.72,  test loss 1.070010, test error 37.00
# Epoch    11, train loss 0.139320, train error 1.47,  test loss 1.050553, test error 36.10
# Epoch    12, train loss 0.116803, train error 0.80,  test loss 1.068919, test error 36.50
# Epoch    13, train loss 0.102084, train error 0.38,  test loss 1.097091, test error 37.90
# Epoch    14, train loss 0.083919, train error 0.15,  test loss 1.120930, test error 37.00
# Epoch    15, train loss 0.073434, train error 0.05,  test loss 1.116449, test error 36.20
# Epoch    16, train loss 0.066452, train error 0.03,  test loss 1.138552, test error 36.40
# Epoch    17, train loss 0.056829, train error 0.03,  test loss 1.151067, test error 36.80
# Epoch    18, train loss 0.050914, train error 0.00,  test loss 1.172294, test error 36.00
# Epoch    19, train loss 0.046542, train error 0.00,  test loss 1.182114, test error 35.90
# Epoch    20, train loss 0.040833, train error 0.00,  test loss 1.185848, test error 36.90
# Epoch    21, train loss 0.038823, train error 0.00,  test loss 1.185986, test error 36.30
# Epoch    22, train loss 0.036723, train error 0.00,  test loss 1.201092, test error 36.50
# Epoch    23, train loss 0.035658, train error 0.00,  test loss 1.206644, test error 36.50
# Epoch    24, train loss 0.033836, train error 0.00,  test loss 1.208856, test error 36.60
# Epoch    25, train loss 0.032161, train error 0.00,  test loss 1.217897, test error 36.20
# Epoch    26, train loss 0.030970, train error 0.00,  test loss 1.218638, test error 36.40
# Epoch    27, train loss 0.029845, train error 0.00,  test loss 1.222378, test error 36.00
# Epoch    28, train loss 0.028625, train error 0.00,  test loss 1.231937, test error 36.40
# Epoch    29, train loss 0.027531, train error 0.00,  test loss 1.236621, test error 36.00
# Epoch    30, train loss 0.026999, train error 0.00,  test loss 1.239873, test error 36.10
# Epoch    31, train loss 0.026504, train error 0.00,  test loss 1.243201, test error 36.30
# Epoch    32, train loss 0.026069, train error 0.00,  test loss 1.246445, test error 36.10
# Epoch    33, train loss 0.025628, train error 0.00,  test loss 1.246967, test error 35.90
# Epoch    34, train loss 0.025133, train error 0.00,  test loss 1.249818, test error 36.00
# Epoch    35, train loss 0.024710, train error 0.00,  test loss 1.254578, test error 36.10
# Epoch    36, train loss 0.024353, train error 0.00,  test loss 1.254043, test error 36.30
# Epoch    37, train loss 0.023918, train error 0.00,  test loss 1.257032, test error 36.20
# Epoch    38, train loss 0.023516, train error 0.00,  test loss 1.260202, test error 36.30
# Epoch    39, train loss 0.023160, train error 0.00,  test loss 1.263903, test error 35.80
# Epoch    40, train loss 0.022941, train error 0.00,  test loss 1.264102, test error 35.90
# Epoch    41, train loss 0.022758, train error 0.00,  test loss 1.263728, test error 35.90
# Epoch    42, train loss 0.022579, train error 0.00,  test loss 1.265599, test error 35.90
# Epoch    43, train loss 0.022423, train error 0.00,  test loss 1.267540, test error 36.00
# Epoch    44, train loss 0.022232, train error 0.00,  test loss 1.268428, test error 35.90
# Epoch    45, train loss 0.022072, train error 0.00,  test loss 1.268758, test error 36.00
# Epoch    46, train loss 0.021898, train error 0.00,  test loss 1.270576, test error 36.00
# Epoch    47, train loss 0.021732, train error 0.00,  test loss 1.271522, test error 35.90
# Epoch    48, train loss 0.021574, train error 0.00,  test loss 1.272624, test error 36.00
# Epoch    49, train loss 0.021412, train error 0.00,  test loss 1.273886, test error 36.00
# Epoch    50, train loss 0.021322, train error 0.00,  test loss 1.274230, test error 35.90
# Epoch    51, train loss 0.021243, train error 0.00,  test loss 1.274891, test error 36.10
# Epoch    52, train loss 0.021164, train error 0.00,  test loss 1.274838, test error 35.90
# Epoch    53, train loss 0.021086, train error 0.00,  test loss 1.275730, test error 36.00
# Epoch    54, train loss 0.021009, train error 0.00,  test loss 1.277013, test error 35.90
# Epoch    55, train loss 0.020932, train error 0.00,  test loss 1.276974, test error 36.10
# Epoch    56, train loss 0.020857, train error 0.00,  test loss 1.277176, test error 36.00
# Epoch    57, train loss 0.020779, train error 0.00,  test loss 1.278233, test error 35.90
# Epoch    58, train loss 0.020705, train error 0.00,  test loss 1.278650, test error 36.00
# Epoch    59, train loss 0.020631, train error 0.00,  test loss 1.279510, test error 35.90
# Epoch    60, train loss 0.020592, train error 0.00,  test loss 1.279408, test error 35.90
# Epoch    61, train loss 0.020554, train error 0.00,  test loss 1.280005, test error 35.90
# Epoch    62, train loss 0.020518, train error 0.00,  test loss 1.280186, test error 36.00
# Epoch    63, train loss 0.020480, train error 0.00,  test loss 1.280644, test error 36.00
# Epoch    64, train loss 0.020443, train error 0.00,  test loss 1.280558, test error 36.00
# Epoch    65, train loss 0.020407, train error 0.00,  test loss 1.280795, test error 35.90
# Epoch    66, train loss 0.020370, train error 0.00,  test loss 1.281234, test error 35.90
# Epoch    67, train loss 0.020335, train error 0.00,  test loss 1.281484, test error 36.00
# Epoch    68, train loss 0.020298, train error 0.00,  test loss 1.281798, test error 36.00
# Epoch    69, train loss 0.020262, train error 0.00,  test loss 1.281957, test error 36.00
# Epoch    70, train loss 0.020243, train error 0.00,  test loss 1.282063, test error 36.00
# Epoch    71, train loss 0.020225, train error 0.00,  test loss 1.282276, test error 36.00
# Epoch    72, train loss 0.020207, train error 0.00,  test loss 1.282429, test error 36.00
# Epoch    73, train loss 0.020189, train error 0.00,  test loss 1.282595, test error 36.00
# Epoch    74, train loss 0.020171, train error 0.00,  test loss 1.282704, test error 36.00
# Epoch    75, train loss 0.020153, train error 0.00,  test loss 1.282884, test error 36.00
# Epoch    76, train loss 0.020136, train error 0.00,  test loss 1.282954, test error 35.90
# Epoch    77, train loss 0.020118, train error 0.00,  test loss 1.283083, test error 36.00
# Epoch    78, train loss 0.020100, train error 0.00,  test loss 1.283264, test error 36.00
# Epoch    79, train loss 0.020083, train error 0.00,  test loss 1.283368, test error 35.90
# Epoch    80, train loss 0.020073, train error 0.00,  test loss 1.283434, test error 36.00
# Epoch    81, train loss 0.020064, train error 0.00,  test loss 1.283533, test error 36.00
# Epoch    82, train loss 0.020055, train error 0.00,  test loss 1.283622, test error 36.00
# Epoch    83, train loss 0.020047, train error 0.00,  test loss 1.283635, test error 36.00
# Epoch    84, train loss 0.020038, train error 0.00,  test loss 1.283786, test error 36.00
# Epoch    85, train loss 0.020029, train error 0.00,  test loss 1.283799, test error 36.00
# Epoch    86, train loss 0.020020, train error 0.00,  test loss 1.283862, test error 36.00
# Epoch    87, train loss 0.020011, train error 0.00,  test loss 1.283923, test error 36.00
# Epoch    88, train loss 0.020003, train error 0.00,  test loss 1.283930, test error 36.00
# Epoch    89, train loss 0.019994, train error 0.00,  test loss 1.284052, test error 36.00
# Epoch    90, train loss 0.019989, train error 0.00,  test loss 1.284106, test error 36.00
# Epoch    91, train loss 0.019985, train error 0.00,  test loss 1.284122, test error 36.00
# Epoch    92, train loss 0.019980, train error 0.00,  test loss 1.284169, test error 36.00
# Epoch    93, train loss 0.019976, train error 0.00,  test loss 1.284188, test error 36.00
# Epoch    94, train loss 0.019972, train error 0.00,  test loss 1.284256, test error 36.00
# Epoch    95, train loss 0.019967, train error 0.00,  test loss 1.284266, test error 36.00
# Epoch    96, train loss 0.019963, train error 0.00,  test loss 1.284265, test error 36.00
# Epoch    97, train loss 0.019959, train error 0.00,  test loss 1.284311, test error 36.00
# Epoch    98, train loss 0.019954, train error 0.00,  test loss 1.284369, test error 36.00
# Epoch    99, train loss 0.019950, train error 0.00,  test loss 1.284407, test error 36.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# Not encouraging. In fact the results are worse.
